# %%
import batch_export_h5
import importlib
importlib.reload(batch_export_h5) # 確保讀到最新修改

FAULT_AREA = 10 * 50 #m^2
SLIDING_AREA = 10 * 12                #m^2# 長方形 (長 x 寬)
# SLIDING_AREA = 7.5 * 7.5 * 3.14159  #m^2# 圓形 (半徑 x 半徑 x pi)

batch_export_h5.batch_export(
    fault_area_cm2=FAULT_AREA,sliding_area_cm2=SLIDING_AREA,
    window_sec=1.0,baseline_block=2,threshold=3,dt_max=0.2,lowpass_fc=500)

# %%
# !python c:/experiment/labquake-explorer-main/export_analysis_csv.py t0148.h5
