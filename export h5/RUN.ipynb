# %%
import sys
sys.path.insert(0, r'c:\experiment\labquake_explorer_re\export h5')
import batch_export_h5
import importlib
importlib.reload(batch_export_h5)

# 1D 實驗
thickness = 10
VW_LENGTH = 12

FAULT_AREA = thickness * 50           #m^2 
SLIDING_AREA = thickness * VW_LENGTH  #m^2# 長方形 (長 x 寬)

batch_export_h5.batch_export(
    fault_area_cm2=FAULT_AREA, sliding_area_cm2=SLIDING_AREA,vw_length_cm=VW_LENGTH,
    window_sec=1.0, baseline_block=2, threshold=3, dt_max=0.2, lowpass_fc=500
)

# %%
import sys
sys.path.insert(0, r'c:\experiment\labquake_explorer_re\export h5')
import batch_export_h5
import importlib
importlib.reload(batch_export_h5)

# 2D 實驗
FAULT_AREA = 50 * 50           #m^2
VW_DIAMETER = 15
SLIDING_AREA = VW_DIAMETER **2 * 3.14159 /4 #m^2# 圓形 (直徑 x 直徑 x pi /4)

batch_export_h5.batch_export(
    fault_area_cm2=FAULT_AREA, sliding_area_cm2=SLIDING_AREA,vw_diameter_cm=VW_DIAMETER,
    window_sec=1.0, baseline_block=2, threshold=3, dt_max=0.2, lowpass_fc=500
)

# %%
# !python c:/experiment/labquake_explorer_re/export_analysis_csv.py t0104.h5
